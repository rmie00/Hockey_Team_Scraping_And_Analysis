# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns

# %%
dat = sqlite3.connect('HockeyDataBase.sqlite')
df = pd.read_sql_query('SELECT * FROM Performance',
                      dat,
                      index_col = ['Team_Name'])

# %%
df.head()
# Out:
#                     Year_Played  Wins  Losses OT_Losses  Goals_For  \
# Team_Name
# Boston Bruins              1990    44      24                  299
# Buffalo Sabres             1990    31      30                  292
# Calgary Flames             1990    46      26                  344
# Chicago Blackhawks         1990    49      23                  284
# Detroit Red Wings          1990    34      38                  273
#
#                     Goals_Against
# Team_Name
# Boston Bruins                 264
# Buffalo Sabres                278
# Calgary Flames                263
# Chicago Blackhawks            211
# Detroit Red Wings             298

# %%
df.describe()
# Out:
#        Year_Played        Wins      Losses   Goals_For  Goals_Against
# count   582.000000  582.000000  582.000000  582.000000     582.000000
# mean   2000.907216   36.943299   32.353952  234.063574     234.063574
# std       6.330674    8.926081    8.411439   40.548915      42.510718
# min    1990.000000    9.000000   11.000000  115.000000     115.000000
# 25%    1996.000000   31.000000   27.000000  211.000000     207.000000
# 50%    2001.000000   38.000000   31.000000  231.000000     232.500000
# 75%    2007.000000   43.000000   37.000000  254.000000     258.750000
# max    2011.000000   62.000000   71.000000  369.000000     414.000000

# %%
df.shape
# Out:
# (582, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 582 entries, Boston Bruins to Winnipeg Jets
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year_Played    582 non-null    int64
#  1   Wins           582 non-null    int64
#  2   Losses         582 non-null    int64
#  3   OT_Losses      582 non-null    object
#  4   Goals_For      582 non-null    int64
#  5   Goals_Against  582 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 31.8+ KB

# %%
df['OT_Losses'] = pd.to_numeric(df['OT_Losses'])
df['OT_Losses'] = (df['OT_Losses'].fillna(0)).astype(int)

# %%
df['Win_Perc'] = round((df['Wins'] / (df['Wins'] + df['Losses']))*100, 2)

# %%
df['+-'] = df['Goals_For'] - df['Goals_Against']

# %%
df = df[['Year_Played', 'Wins', 'Losses','OT_Losses', 'Win_Perc', 'Goals_For', 'Goals_Against', '+-']]

# %%
df_top = df[df['Wins'] == df.groupby('Year_Played')['Wins'].transform(max)]
df_top
# Out:
#                      Year_Played  Wins  Losses  OT_Losses  Win_Perc  \
# Team_Name
# Chicago Blackhawks          1990    49      23          0     68.06
# New York Rangers            1991    50      25          0     66.67
# Pittsburgh Penguins         1992    56      21          0     72.73
# New York Rangers            1993    52      24          0     68.42
# Detroit Red Wings           1994    33      11          0     75.00
# Detroit Red Wings           1995    62      13          0     82.67
# Colorado Avalanche          1996    49      24          0     67.12
# Dallas Stars                1997    49      22          0     69.01
# Dallas Stars                1998    51      19          0     72.86
# St. Louis Blues             1999    51      19          1     72.86
# Colorado Avalanche          2000    52      16          4     76.47
# Detroit Red Wings           2001    51      17          4     75.00
# Ottawa Senators             2002    52      21          1     71.23
# Detroit Red Wings           2003    48      21          2     69.57
# Detroit Red Wings           2005    58      16          8     78.38
# Buffalo Sabres              2006    53      22          7     70.67
# Detroit Red Wings           2007    54      21          7     72.00
# Boston Bruins               2008    53      19         10     73.61
# San Jose Sharks             2008    53      18         11     74.65
# Washington Capitals         2009    54      15         13     78.26
# Vancouver Canucks           2010    54      19          9     73.97
# New York Rangers            2011    51      24          7     68.00
# Pittsburgh Penguins         2011    51      25          6     67.11
# Vancouver Canucks           2011    51      22          9     69.86
#
#                      Goals_For  Goals_Against   +-
# Team_Name
# Chicago Blackhawks         284            211   73
# New York Rangers           321            246   75
# Pittsburgh Penguins        367            268   99
# New York Rangers           299            231   68
# Detroit Red Wings          180            117   63
# Detroit Red Wings          325            181  144
# Colorado Avalanche         277            205   72
# Dallas Stars               242            167   75
# Dallas Stars               236            168   68
# St. Louis Blues            248            165   83
# Colorado Avalanche         270            192   78
# Detroit Red Wings          251            187   64
# Ottawa Senators            263            182   81
# Detroit Red Wings          255            189   66
# Detroit Red Wings          305            209   96
# Buffalo Sabres             308            242   66
# Detroit Red Wings          257            184   73
# Boston Bruins              274            196   78
# San Jose Sharks            257            204   53
# Washington Capitals        318            233   85
# Vancouver Canucks          262            185   77
# New York Rangers           226            187   39
# Pittsburgh Penguins        282            221   61
# Vancouver Canucks          249            198   51

# %%
df_top = df.reset_index()
df_top = df_top.sort_values(by=['Wins', '+-'], ascending = False)
df_top = df_top.groupby('Year_Played').first()[['Team_Name', 'Wins', 'Losses','OT_Losses', 'Win_Perc', 'Goals_For', 'Goals_Against', '+-']]
df_top.reset_index(inplace=True)
df_top.set_index('Team_Name', inplace=True)
df_top
# Out:
#                      Year_Played  Wins  Losses  OT_Losses  Win_Perc  \
# Team_Name
# Chicago Blackhawks          1990    49      23          0     68.06
# New York Rangers            1991    50      25          0     66.67
# Pittsburgh Penguins         1992    56      21          0     72.73
# New York Rangers            1993    52      24          0     68.42
# Detroit Red Wings           1994    33      11          0     75.00
# Detroit Red Wings           1995    62      13          0     82.67
# Colorado Avalanche          1996    49      24          0     67.12
# Dallas Stars                1997    49      22          0     69.01
# Dallas Stars                1998    51      19          0     72.86
# St. Louis Blues             1999    51      19          1     72.86
# Colorado Avalanche          2000    52      16          4     76.47
# Detroit Red Wings           2001    51      17          4     75.00
# Ottawa Senators             2002    52      21          1     71.23
# Detroit Red Wings           2003    48      21          2     69.57
# Detroit Red Wings           2005    58      16          8     78.38
# Buffalo Sabres              2006    53      22          7     70.67
# Detroit Red Wings           2007    54      21          7     72.00
# Boston Bruins               2008    53      19         10     73.61
# Washington Capitals         2009    54      15         13     78.26
# Vancouver Canucks           2010    54      19          9     73.97
# Pittsburgh Penguins         2011    51      25          6     67.11
#
#                      Goals_For  Goals_Against   +-
# Team_Name
# Chicago Blackhawks         284            211   73
# New York Rangers           321            246   75
# Pittsburgh Penguins        367            268   99
# New York Rangers           299            231   68
# Detroit Red Wings          180            117   63
# Detroit Red Wings          325            181  144
# Colorado Avalanche         277            205   72
# Dallas Stars               242            167   75
# Dallas Stars               236            168   68
# St. Louis Blues            248            165   83
# Colorado Avalanche         270            192   78
# Detroit Red Wings          251            187   64
# Ottawa Senators            263            182   81
# Detroit Red Wings          255            189   66
# Detroit Red Wings          305            209   96
# Buffalo Sabres             308            242   66
# Detroit Red Wings          257            184   73
# Boston Bruins              274            196   78
# Washington Capitals        318            233   85
# Vancouver Canucks          262            185   77
# Pittsburgh Penguins        282            221   61

# %%
df_bottom = df.reset_index()
df_bottom = df_bottom.sort_values(['Wins','+-'])
df_bottom = df_bottom.groupby('Year_Played').first()[['Team_Name', 'Wins', 'Losses','OT_Losses', 'Win_Perc', 'Goals_For', 'Goals_Against', '+-']]
df_bottom.reset_index(inplace=True)
df_bottom.set_index('Team_Name', inplace=True)
df_bottom
# Out:
#                        Year_Played  Wins  Losses  OT_Losses  Win_Perc  \
# Team_Name
# Quebec Nordiques              1990    16      50          0     24.24
# San Jose Sharks               1991    17      58          0     22.67
# Ottawa Senators               1992    10      70          0     12.50
# Ottawa Senators               1993    14      61          0     18.67
# Ottawa Senators               1994     9      34          0     20.93
# Ottawa Senators               1995    18      59          0     23.38
# Boston Bruins                 1996    26      47          0     35.62
# Tampa Bay Lightning           1997    17      55          0     23.61
# Tampa Bay Lightning           1998    19      54          0     26.03
# Atlanta Thrashers             1999    14      57          4     19.72
# New York Islanders            2000    21      51          3     29.17
# Atlanta Thrashers             2001    19      47          5     28.79
# Carolina Hurricanes           2002    22      43          6     33.85
# Chicago Blackhawks            2003    20      43          8     31.75
# St. Louis Blues               2005    21      46         15     31.34
# Philadelphia Flyers           2006    22      48         12     31.43
# Tampa Bay Lightning           2007    31      42          9     42.47
# Tampa Bay Lightning           2008    24      40         18     37.50
# Edmonton Oilers               2009    27      47          8     36.49
# Edmonton Oilers               2010    25      45         12     35.71
# Columbus Blue Jackets         2011    29      46          7     38.67
#
#                        Goals_For  Goals_Against   +-
# Team_Name
# Quebec Nordiques             236            354 -118
# San Jose Sharks              219            359 -140
# Ottawa Senators              202            395 -193
# Ottawa Senators              201            397 -196
# Ottawa Senators              117            174  -57
# Ottawa Senators              191            291 -100
# Boston Bruins                234            300  -66
# Tampa Bay Lightning          151            269 -118
# Tampa Bay Lightning          179            292 -113
# Atlanta Thrashers            170            313 -143
# New York Islanders           185            268  -83
# Atlanta Thrashers            187            288 -101
# Carolina Hurricanes          171            240  -69
# Chicago Blackhawks           188            259  -71
# St. Louis Blues              197            292  -95
# Philadelphia Flyers          214            303  -89
# Tampa Bay Lightning          223            267  -44
# Tampa Bay Lightning          210            279  -69
# Edmonton Oilers              214            284  -70
# Edmonton Oilers              193            269  -76
# Columbus Blue Jackets        202            262  -60

# %%
bar_plot_wins_losses = pd.DataFrame({
    'Team Type': ['Average', 'Top Teams', 'Bottom Teams'],
    'Wins': [df['Wins'].mean(), df_top['Wins'].mean(), df_bottom['Wins'].mean()],
    'Losses': [df['Losses'].mean(), df_top['Losses'].mean(), df_bottom['Losses'].mean()]
})

bar_plot_goals = pd.DataFrame({
    'Team Type': ['Average', 'Top Teams', 'Bottom Teams'],
    'Goals_For': [df['Goals_For'].mean(), df_top['Goals_For'].mean(), df_bottom['Goals_For'].mean()],
    'Goals_Against': [df['Goals_Against'].mean(), df_top['Goals_Against'].mean(), df_bottom['Goals_Against'].mean()]
})

bar_plot_wins_losses_melted = bar_plot_wins_losses.melt(id_vars='Team Type', var_name='Metric', value_name='Average Value')
bar_plot_goals_melted = bar_plot_goals.melt(id_vars='Team Type', var_name='Metric', value_name='Average Value')


plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.barplot(x='Metric', y='Average Value', hue='Team Type', data=bar_plot_wins_losses_melted, palette = ['grey', 'green', 'red'])
plt.title('Bar Chart for Wins and Losses')

plt.subplot(1, 2, 2)
sns.barplot(x='Metric', y='Average Value', hue='Team Type', data=bar_plot_goals_melted, palette = ['grey', 'green', 'red'])
plt.title('Bar Chart for Goals')
# Out:
# Text(0.5, 1.0, 'Bar Chart for Goals')

# %%
correlation = df.corr()
mask = np.triu(np.ones_like(correlation, dtype=bool))
mask
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True,  True],
#        [False,  True,  True,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True,  True],
#        [False, False, False, False, False,  True,  True,  True],
#        [False, False, False, False, False, False,  True,  True],
#        [False, False, False, False, False, False, False,  True]])

# %%
palette = sns.color_palette('coolwarm', 12)
fig ,axe = plt.subplots(figsize = (14,6))
sns.heatmap(data = correlation,
            mask = mask,
           square = True,
           cmap = palette,
           linewidth = 0.5,
           annot = True,
           fmt = '.2f')
axe.set_title('Correlation Map')
# Out:
# Text(0.5, 1.0, 'Correlation Map')

# %%
grouped_teams = df.groupby('Team_Name')
team_df = {}
for name, data in grouped_teams:
    team_df[name] = data.copy()
team_df['Pittsburgh Penguins']
# Out:
#                      Year_Played  Wins  Losses  OT_Losses  Win_Perc  \
# Team_Name
# Pittsburgh Penguins         1990    41      33          0     55.41
# Pittsburgh Penguins         1991    39      32          0     54.93
# Pittsburgh Penguins         1992    56      21          0     72.73
# Pittsburgh Penguins         1993    44      27          0     61.97
# Pittsburgh Penguins         1994    29      16          0     64.44
# Pittsburgh Penguins         1995    49      29          0     62.82
# Pittsburgh Penguins         1996    38      36          0     51.35
# Pittsburgh Penguins         1997    40      24          0     62.50
# Pittsburgh Penguins         1998    38      30          0     55.88
# Pittsburgh Penguins         1999    37      31          6     54.41
# Pittsburgh Penguins         2000    42      28          3     60.00
# Pittsburgh Penguins         2001    28      41          5     40.58
# Pittsburgh Penguins         2002    27      44          5     38.03
# Pittsburgh Penguins         2003    23      47          4     32.86
# Pittsburgh Penguins         2005    22      46         14     32.35
# Pittsburgh Penguins         2006    47      24         11     66.20
# Pittsburgh Penguins         2007    47      27          8     63.51
# Pittsburgh Penguins         2008    45      28          9     61.64
# Pittsburgh Penguins         2009    47      28          7     62.67
# Pittsburgh Penguins         2010    49      25          8     66.22
# Pittsburgh Penguins         2011    51      25          6     67.11
#
#                      Goals_For  Goals_Against   +-
# Team_Name
# Pittsburgh Penguins        342            305   37
# Pittsburgh Penguins        343            308   35
# Pittsburgh Penguins        367            268   99
# Pittsburgh Penguins        299            285   14
# Pittsburgh Penguins        181            158   23
# Pittsburgh Penguins        362            284   78
# Pittsburgh Penguins        285            280    5
# Pittsburgh Penguins        228            188   40
# Pittsburgh Penguins        242            225   17
# Pittsburgh Penguins        241            236    5
# Pittsburgh Penguins        281            256   25
# Pittsburgh Penguins        198            249  -51
# Pittsburgh Penguins        189            255  -66
# Pittsburgh Penguins        190            303 -113
# Pittsburgh Penguins        244            316  -72
# Pittsburgh Penguins        277            246   31
# Pittsburgh Penguins        247            216   31
# Pittsburgh Penguins        264            239   25
# Pittsburgh Penguins        257            237   20
# Pittsburgh Penguins        238            199   39
# Pittsburgh Penguins        282            221   61

# %%
season_win_count = df_top.groupby('Team_Name')['Year_Played'].nunique().to_dict()
sorted(season_win_count.items())
# Out:
# [('Boston Bruins', 1),
#  ('Buffalo Sabres', 1),
#  ('Chicago Blackhawks', 1),
#  ('Colorado Avalanche', 2),
#  ('Dallas Stars', 2),
#  ('Detroit Red Wings', 6),
#  ('New York Rangers', 2),
#  ('Ottawa Senators', 1),
#  ('Pittsburgh Penguins', 2),
#  ('St. Louis Blues', 1),
#  ('Vancouver Canucks', 1),
#  ('Washington Capitals', 1)]
